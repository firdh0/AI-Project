# %% [markdown]
# <a href="https://colab.research.google.com/github/firdh0/AI-Project/blob/main/%F0%9F%8F%97%EF%B8%8F_04_Create_Tokenizer_URL_Random_After_Preprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📢 File explanation!!

# %% [markdown]
# Pada file ini bertujuan untuk membuat corpus dari dataset df_url_random_after_preprocess_2.csv yang telah dipreprocessing pada file 03

# %% [markdown]
# # 🎯 **Step 0: Import library**
# ---

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import json

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
plt.style.use('seaborn')
# Out:
# <ipython-input-2-4a43041a1d49>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 🎯 **Step 1: Load Dataset**
# ---

# %%
path = '/content/drive/MyDrive/TUGAS AKHIR/Notebook/URL/CNN/RANDOM DATA/PREPROCESS/df_url_random_after_preprocess_2.csv'

df_url = pd.read_csv(path)

df_url.head()
# Out:
#    Category                                 clean_url_sentence  url_length
# 0  phishing  servarsaclie 1 afde90 ingres bonde easywp com ...         113
# 1  phishing                                      maisonleblanc          13
# 2  phishing                           matthewsuch com n26 link          24
# 3  phishing           chat whatsapg com iqp5wvr9bm58omi82nszze          40
# 4  phishing                               dilscordilgis com lt          20

# %% [markdown]
# # 🎯 **Step 2: Split data into feature and label**
# ---

# %%
X = df_url['clean_url_sentence']

y = df_url['Category']

# %% [markdown]
# # 🎯 **Step 3: Processing X**
# ---

# %% [markdown]
# ## ✨ 3.1 - Create Char Level Corpus for Tokenizing and Padding

# %%
# X = [str(url) for url in X]

tokenizer_char_level = Tokenizer(num_words=None, oov_token='<OOV>', char_level=True)
tokenizer_char_level.fit_on_texts(X)
# X_sequences_char_level = tokenizer_char_level.texts_to_sequences(X)
# X_padded_char_level = pad_sequences(X_sequences_char_level, padding='post', truncating='post', maxlen=2000)

# # Build vocabulary
# vocab_size_char_level = len(tokenizer_char_level.word_index) + 1

# X_padded_char_level

# %%
len(tokenizer_char_level.word_index)
# Out:
# 38

# %%
tokenizer_char_level.word_index
# Out:
# {'<OOV>': 1,
#  ' ': 2,
#  'e': 3,
#  'a': 4,
#  'o': 5,
#  'i': 6,
#  'c': 7,
#  'n': 8,
#  't': 9,
#  'r': 10,
#  's': 11,
#  'm': 12,
#  'l': 13,
#  'd': 14,
#  'p': 15,
#  'u': 16,
#  'b': 17,
#  'h': 18,
#  'g': 19,
#  'f': 20,
#  '2': 21,
#  '0': 22,
#  '1': 23,
#  'v': 24,
#  'y': 25,
#  'k': 26,
#  'w': 27,
#  '3': 28,
#  '8': 29,
#  '4': 30,
#  '5': 31,
#  '6': 32,
#  '9': 33,
#  '7': 34,
#  'x': 35,
#  'z': 36,
#  'j': 37,
#  'q': 38}

# %%
tokenizer_char_json = tokenizer_char_level.to_json()

# Menyimpan representasi JSON ke dalam sebuah file
with open('/content/drive/MyDrive/TUGAS AKHIR/Notebook/URL/CNN/RANDOM DATA/PREPROCESS/tokenizer_char_level_random_after_preprocess.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_char_json))

# %% [markdown]
# ## ✨ 3.1 - Create Word Level Corpus for Tokenizing and Padding

# %%
tokenizer_word_level = Tokenizer(num_words=None, oov_token='<OOV>')
tokenizer_word_level.fit_on_texts(X)
# X_sequences_word_level = tokenizer_word_level.texts_to_sequences(X)
# X_padded_word_level = pad_sequences(X_sequences_word_level, padding='post', truncating='post', maxlen=2000)

# # Build vocabulary
# vocab_size_word_level = len(tokenizer_word_level.word_index) + 1

# X_padded_word_level

# %%
len(tokenizer_word_level.word_index)
# Out:
# 1025542

# %%
tokenizer_word_level.word_index
# Out:
# {'<OOV>': 1,
#  'com': 2,
#  'php': 3,
#  'html': 4,
#  'org': 5,
#  'login': 6,
#  'de': 7,
#  'co': 8,
#  'net': 9,
#  'ru': 10,
#  'index': 11,
#  'id': 12,
#  'en': 13,
#  'file': 14,
#  'amp': 15,
#  '1': 16,
#  'd8': 17,
#  'wp': 18,
#  'page1': 19,
#  'top': 20,
#  'app': 21,
#  'category': 22,
#  'u': 23,
#  'uk': 24,
#  'cn': 25,
#  'duckdns': 26,
#  'page': 27,
#  'jp': 28,
#  '2022': 29,
#  'news': 30,
#  'd9': 31,
#  'content': 32,
#  'web': 33,
#  'home': 34,
#  'e': 35,
#  'fr': 36,
#  'info': 37,
#  'service': 38,
#  'd0': 39,
#  'online': 40,
#  '0': 41,
#  '2': 42,
#  'product': 43,
#  'c': 44,
#  'dev': 45,
#  'edu': 46,
#  'xyz': 47,
#  '10': 48,
#  'auth': 49,
#  'htm': 50,
#  'r': 51,
#  'br': 52,
#  '000webhostapp': 53,
#  'e3': 54,
#  'pl': 55,
#  'email': 56,
#  'uwbrvz8quj': 57,
#  'io': 58,
#  'au': 59,
#  'site': 60,
#  'ipfs': 61,
#  'secure': 62,
#  'session': 63,
#  'facebook': 64,
#  'tag': 65,
#  'cmd': 66,
#  'account': 67,
#  'x': 68,
# ...

# %%
tokenizer_word_json = tokenizer_word_level.to_json()

# Menyimpan representasi JSON ke dalam sebuah file
with open('/content/drive/MyDrive/TUGAS AKHIR/Notebook/URL/CNN/RANDOM DATA/PREPROCESS/tokenizer_word_level_after_preprocess.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_word_json))
